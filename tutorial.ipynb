# %% [markdown]
# # Welcome to the DSI CORGIS data Tutorial!
# Today you will examine a dataset provided by the CORGIS dataset project and at the end of this tutorial you will be able to create beautiful graphs with little programming experience!

# %%
# taken from: https://corgis-edu.github.io/corgis/python/graduates/

# %% [markdown]
# # The Dataset we will be using today comes from the CORGIS Dataset project shown here:
#
# <div>
# <img src="attachment:grads_webpage.PNG" width="400"/>
# </div>
#
# You can view the contents of the dataset by clicking "Explore graduates Data" on this webpage: https://corgis-edu.github.io/corgis/python/graduates/
#
# The files `graduates.py` and `graduates.data` should be in the same folder as this notebook

# %% [markdown]
# # Imports
#
# First lets import all the packages we will need:
#
# `graduates` : This is the CORGIS package used to interface with `graduates.data`
#
# `seaborn` : Graphing package built on top of popular library `matplotlib`

# %%
import graduates as g
import seaborn as sns
import pandas as pd

# %%
grad_major = g.get_grad_major()
""" list = [ # each list entry is a dictionary corresponds to a year for a specific major
            {
                "Year": int,
                "Demographics": dict,
                "Education": dict,
                "Salaries": dict,
                "Employment": dict
            },
            {...},
            {...},
            ...
        ]
"""
# Out:
# ' list = [ # each list entry is a dictionary corresponds to a year for a specific major\n            {\n                "Year": int,\n                "Demographics": dict,\n                "Education": dict,\n                "Salaries": dict,\n                "Employment": dict\n            },\n            {...},\n            {...},\n            ...\n        ]\n'

# %%
#                     "Year": cs_years * 2,
#                     "Major": ["Psych"] * len(psy_num_degs) + ["CS"] * len(cs_num_degs) ,
#                     "Degrees":psy_num_degs + cs_num_degs
dictionary = {
                    "Year": cs_years * 2,
                    "Major": ["Psych"] * len(psy_num_degs) + ["CS"] * len(cs_num_degs) ,
                    "Degrees":psy_num_degs + cs_num_degs
                    }
df = pd.DataFrame(dictionary)
df
# Out:
#     Year  Major  Degrees
# 0   1993  Psych  1301889
# 1   1995  Psych  1404991
# 2   1997  Psych  1520163
# 3   1999  Psych  1619802
# 4   2001  Psych   173766
# 5   2003  Psych  1846866
# 6   2006  Psych   289435
# 7   2008  Psych   224705
# 8   2010  Psych  2734299
# 9   2013  Psych  3063565
# 10  2015  Psych  3355678
# 11  1993     CS  1070111
# 12  1995     CS  1114519
# 13  1997     CS  1168978
# 14  1999     CS  1221788
# 15  2001     CS    99579
# 16  2003     CS  1379971
# 17  2006     CS   237830
# 18  2008     CS   144782
# 19  2010     CS  1981187
# 20  2013     CS  2242124
# 21  2015     CS  2489621

# %% [markdown]
# # How many degrees were awarded in Computer Science and Math per year?

# %%
# extract degrees awarded

cs_num_degs = [x["Demographics"]["Total"] for x in grad_major 
            if x["Education"]["Major"] == 'Computer Science and Math']

# extract years they were awarded

cs_years = [x["Year"] for x in grad_major 
            if x["Education"]["Major"] == 'Computer Science and Math']

# %%
# What do our lists look like?
print("Total Degrees awarded in Comp Sci and Math per year\n")
print(cs_years)
print(cs_num_degs)
# Out:
# Total Degrees awarded in Comp Sci and Math per year
#
# [1993, 1995, 1997, 1999, 2001, 2003, 2006, 2008, 2010, 2013, 2015]
# [1070111, 1114519, 1168978, 1221788, 99579, 1379971, 237830, 144782, 1981187, 2242124, 2489621]

# %%
fig = px.bar(x=cs_years, y=cs_num_degs)
fig.show()
# Out:
# <div>                            <div id="f17de0d8-1b86-4ff4-883c-ec2bfb2cccc6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f17de0d8-1b86-4ff4-883c-ec2bfb2cccc6")) {                    Plotly.newPlot(                        "f17de0d8-1b86-4ff4-883c-ec2bfb2cccc6",                        [{"alignmentgroup": "True", "hovertemplate": "x=%{x}<br>y=%{y}<extra></extra>", "legendgroup": "", "marker": {"color": "#636efa"}, "name": "", "offsetgroup": "", "orientation": "v", "showlegend": false, "textposition": "auto", "type": "bar", "x": [1993, 1995, 1997, 1999, 2001, 2003, 2006, 2008, 2010, 2013, 2015], "xaxis": "x", "y": [1070111, 1114519, 1168978, 1221788, 99579, 1379971, 237830, 144782, 1981187, 2242124, 2489621], "yaxis": "y"}],                      
# ...

# %%
ax = sns.barplot(data=df, x="Year", y="Degrees", hue="Major")
n = ax.set_title("CS/Math Degrees per Year")
n = ax.set(xlabel='Year', ylabel='Degrees Awarded')

# %%
ax = sns.barplot(x="", y=cs_num_degs, data=grad_major
                 
n = ax.set_title("CS/Math Degrees per Year")
n = ax.set(xlabel='Year', ylabel='Degrees Awarded')

# %%
# lets plot it
x_pos = [i for i, _ in enumerate(cs_years)]

plt.bar(x_pos,cs_num_degs)
plt.xlabel("Year")
plt.ylabel("Degrees Awarded")
plt.title("Comp Sci and Math Degrees Awarded Yearly")

plt.xticks(x_pos, cs_years)

plt.show()

# %%
# lets compare Comp Sci to Psychology
psy_num_degs = [x["Demographics"]["Total"] for x in grad_major 
            if x["Education"]["Major"] == 'Psychology']


psy_years = [x["Year"] for x in grad_major 
            if x["Education"]["Major"] == 'Psychology' ]

# %%
# What do the lists look like?
print("Total Degrees awarded in Psychology per year\n")
print(psy_years)
print(psy_num_degs)

# %%
width = 1.0 #how far apart the bars will be

ax = plt.subplot(111)
psy_bar = ax.bar(psy_years, psy_num_degs, width=width, color='b', align='center')
cs_bar = ax.bar([x + 1 for x in psy_years], cs_num_degs, width=width, color='g', align='center')

plt.title("CS/Math vs Psychology Degrees Awarded Yearly")
ax.legend( (psy_bar[0], cs_bar[0], ), ('Psychology', 'CS and Math') )


plt.show()

# %%
# Unable to replicate this on CORGIS visualizer, their framework was on much more general relationships
